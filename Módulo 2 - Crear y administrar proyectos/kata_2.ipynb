# %% [markdown]
# # Ejercicio - Crear un paquete
# En este ejercicio, aprenderás a utilizar entornos virtuales como una forma para no afectar a los paquetes instalados globalmente u otros programas que se ejecutan en tu máquina.
#
# Para este ejercicio es necesario que lo ejecutes desde la terminal, línea de comandos, cmd, consola, cli, etc. de tu computadora, sé que es desafíante, pero no te preocupes ¡¡Sé que puedes lograrlo!!
# ## Crear un entorno virtual
# Crea un entorno virtual mediante `venv`
#  - Ejecutar en su terminal: `python3 -m venv env` o bien `python -m venv env`
#
# ```python
#    python3 -m venv env
# ```
# ## Instalar una biblioteca
# Ahora que estás dentro de tu entorno virtual, puedes instalar una biblioteca y saber que la biblioteca solo existirá en el entorno virtual.
#
# -Ejecuta el comando `pip freeze` para ver las bibliotecas instaladas en tu entorno:

# %%
# !pip freeze
# Out:
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# asttokens==2.0.5
# attrs==21.2.0
# Automat==20.2.0
# autopep8==1.5.5
# backcall==0.2.0
# backports.entry-points-selectable==1.1.0
# black==22.1.0
# bleach==4.1.0
# cachetools==4.2.2
# calmjs.parse==1.2.5
# certifi==2021.5.30
# cffi==1.14.6
# cfscrape==2.1.1
# charset-normalizer==2.0.4
# click==8.0.3
# colorama==0.4.4
# constantly==15.1.0
# cryptography==3.4.7
# cssselect==1.1.0
# cycler==0.11.0
# debugpy==1.5.1
# decorator==5.1.1
# defusedxml==0.7.1
# distlib==0.3.2
# elasticsearch==7.14.0
# entrypoints==0.4
# executing==0.8.2
# Faker==11.3.0
# filelock==3.0.12
# Flask==2.0.2
# fonttools==4.29.0
# future==0.18.2
# h2==3.2.0
# hpack==3.0.0
# hyperframe==5.2.0
# hyperlink==21.0.0
# idna==3.2
# incremental==21.3.0
# ipykernel==6.9.0
# ipython==8.0.1
# ipython-genutils==0.2.0
# ipywidgets==7.6.5
# itemadapter==0.3.0
# itemloaders==1.0.4
# itsdangerous==2.0.1
# jedi==0.18.1
# Jinja2==3.0.3
# jmespath==0.10.0
# joblib==1.1.0
# js2xml==0.4.0
# jsonschema==4.4.0
# jupyter==1.0.0
# jupyter-client==7.1.2
# jupyter-console==6.4.0
# jupyter-core==4.9.1
# jupyterlab-pygments==0.1.2
# jupyterlab-widgets==1.0.2
# kiwisolver==1.3.2
# lxml==4.6.3
# MarkupSafe==2.0.1
# matplotlib==3.5.1
# matplotlib-inline==0.1.3
# mistune==0.8.4
# mypy-extensions==0.4.3
# nbclient==0.5.10
# nbconvert==6.4.2
# nbformat==5.1.3
# nest-asyncio==1.5.4
# notebook==6.4.8
# numpy==1.22.1
# packaging==21.3
# pandocfilters==1.5.0
# parsel==1.6.0
# parso==0.8.3
# pathspec==0.9.0
# pefile==2021.5.24
# pickleshare==0.7.5
# Pillow==9.0.0
# platformdirs==2.3.0
# ply==3.11
# priority==1.3.0
# prometheus-client==0.13.1
# prompt-toolkit==3.0.27
# Protego==0.1.16
# pure-eval==0.2.2
# py2exe==0.10.4.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycodestyle==2.6.0
# pycparser==2.20
# PyDispatcher==2.0.5
# Pygments==2.11.2
# pyOpenSSL==20.0.1
# pyparsing==3.0.7
# PyQt5==5.15.4
# pyqt5-plugins==5.15.4.2.2
# PyQt5-Qt5==5.15.2
# PyQt5-sip==12.9.0
# PyQt5-stubs==5.15.2.0
# pyqt5-tools==5.15.4.3.2
# PyQt5Designer==5.14.1
# pyrsistent==0.18.1
# python-dateutil==2.8.2
# python-dotenv==0.19.2
# pywin32==303
# pywinpty==2.0.2
# pyzmq==22.3.0
# qt5-applications==5.15.2.2.2
# qt5-tools==5.15.2.1.2
# qtconsole==5.2.2
# QtPy==2.0.1
# queuelib==1.6.1
# requests==2.26.0
# scikit-learn==1.0.2
# scipy==1.7.3
# Scrapy==2.5.0
# Send2Trash==1.8.0
# service-identity==21.1.0
# six==1.16.0
# stack-data==0.1.4
# terminado==0.13.1
# testpath==0.5.0
# text-unidecode==1.3
# threadpoolctl==3.1.0
# toml==0.10.2
# tomli==2.0.1
# tornado==6.1
# traitlets==5.1.1
# Twisted==21.7.0
# twisted-iocpsupport==1.0.1
# typing-extensions==3.10.0.0
# urllib3==1.26.6
# virtualenv==20.7.2
# virtualenvwrapper-win==1.2.6
# w3lib==1.22.0
# wcwidth==0.2.5
# webencodings==0.5.1
# Werkzeug==2.0.2
# widgetsnbextension==3.5.2
# zope.interface==5.4.0

# %% [markdown]
# -Ejecuta el comando `pip install` para instalar una biblioteca:

# %%
pip install python-dateutil
# Out:
# Requirement already satisfied: python-dateutil in c:\users\toromax\desktop\cursos\python\test\lib\site-packages (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\toromax\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\ToroMax\Desktop\Cursos\Python\test\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip freeze
# Out:
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# asttokens==2.0.5
# attrs==21.2.0
# Automat==20.2.0
# autopep8==1.5.5
# backcall==0.2.0
# backports.entry-points-selectable==1.1.0
# black==22.1.0
# bleach==4.1.0
# cachetools==4.2.2
# calmjs.parse==1.2.5
# certifi==2021.5.30
# cffi==1.14.6
# cfscrape==2.1.1
# charset-normalizer==2.0.4
# click==8.0.3
# colorama==0.4.4
# constantly==15.1.0
# cryptography==3.4.7
# cssselect==1.1.0
# cycler==0.11.0
# debugpy==1.5.1
# decorator==5.1.1
# defusedxml==0.7.1
# distlib==0.3.2
# elasticsearch==7.14.0
# entrypoints==0.4
# executing==0.8.2
# Faker==11.3.0
# filelock==3.0.12
# Flask==2.0.2
# fonttools==4.29.0
# future==0.18.2
# h2==3.2.0
# hpack==3.0.0
# hyperframe==5.2.0
# hyperlink==21.0.0
# idna==3.2
# incremental==21.3.0
# ipykernel==6.9.0
# ipython==8.0.1
# ipython-genutils==0.2.0
# ipywidgets==7.6.5
# itemadapter==0.3.0
# itemloaders==1.0.4
# itsdangerous==2.0.1
# jedi==0.18.1
# Jinja2==3.0.3
# jmespath==0.10.0
# joblib==1.1.0
# js2xml==0.4.0
# jsonschema==4.4.0
# jupyter==1.0.0
# jupyter-client==7.1.2
# jupyter-console==6.4.0
# jupyter-core==4.9.1
# jupyterlab-pygments==0.1.2
# jupyterlab-widgets==1.0.2
# kiwisolver==1.3.2
# lxml==4.6.3
# MarkupSafe==2.0.1
# matplotlib==3.5.1
# matplotlib-inline==0.1.3
# mistune==0.8.4
# mypy-extensions==0.4.3
# nbclient==0.5.10
# nbconvert==6.4.2
# nbformat==5.1.3
# nest-asyncio==1.5.4
# notebook==6.4.8
# numpy==1.22.1
# packaging==21.3
# pandocfilters==1.5.0
# parsel==1.6.0
# parso==0.8.3
# pathspec==0.9.0
# pefile==2021.5.24
# pickleshare==0.7.5
# Pillow==9.0.0
# platformdirs==2.3.0
# ply==3.11
# priority==1.3.0
# prometheus-client==0.13.1
# prompt-toolkit==3.0.27
# Protego==0.1.16
# pure-eval==0.2.2
# py2exe==0.10.4.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycodestyle==2.6.0
# pycparser==2.20
# PyDispatcher==2.0.5
# Pygments==2.11.2
# pyOpenSSL==20.0.1
# pyparsing==3.0.7
# PyQt5==5.15.4
# pyqt5-plugins==5.15.4.2.2
# PyQt5-Qt5==5.15.2
# PyQt5-sip==12.9.0
# PyQt5-stubs==5.15.2.0
# pyqt5-tools==5.15.4.3.2
# PyQt5Designer==5.14.1
# pyrsistent==0.18.1
# python-dateutil==2.8.2
# python-dotenv==0.19.2
# pywin32==303
# pywinpty==2.0.2
# pyzmq==22.3.0
# qt5-applications==5.15.2.2.2
# qt5-tools==5.15.2.1.2
# qtconsole==5.2.2
# QtPy==2.0.1
# queuelib==1.6.1
# requests==2.26.0
# scikit-learn==1.0.2
# scipy==1.7.3
# Scrapy==2.5.0
# Send2Trash==1.8.0
# service-identity==21.1.0
# six==1.16.0
# stack-data==0.1.4
# terminado==0.13.1
# testpath==0.5.0
# text-unidecode==1.3
# threadpoolctl==3.1.0
# toml==0.10.2
# tomli==2.0.1
# tornado==6.1
# traitlets==5.1.1
# Twisted==21.7.0
# twisted-iocpsupport==1.0.1
# typing-extensions==3.10.0.0
# urllib3==1.26.6
# virtualenv==20.7.2
# virtualenvwrapper-win==1.2.6
# w3lib==1.22.0
# wcwidth==0.2.5
# webencodings==0.5.1
# Werkzeug==2.0.2
# widgetsnbextension==3.5.2
# zope.interface==5.4.0

# %%
#deactivate en consola
